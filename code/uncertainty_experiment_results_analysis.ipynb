# %%
# !pip install neptune -q
# !pip install neptune-fetcher -q

# %% [markdown]
# ### вычисление результатов

# %%
import numpy as np
import pandas as pd
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import neptune
sns.set_style('whitegrid')

# %%
run = neptune.init_run(
    project="e2001092236e/Uncertainty",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxMGYzYjI3OS0xZjAyLTRmMmMtOTcwNi04MGE0Y2FlODBjNjMifQ==",
    with_id="UN-19"
)  # your credentials
# Out:
# [neptune] [warning] NeptuneWarning: By default, these monitoring options are disabled in interactive sessions: 'capture_stdout', 'capture_stderr', 'capture_traceback', 'capture_hardware_metrics'. You can set them to 'True' when initializing the run and the monitoring will continue until you call run.stop() or the kernel stops. NOTE: To track the source files, pass their paths to the 'source_code' argument. For help, see: https://docs.neptune.ai/logging/source_code/
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/e2001092236e/Uncertainty/e/UN-19

# %%
run = neptune.init_run(
    project="e2001092236e/Uncertainty",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxMGYzYjI3OS0xZjAyLTRmMmMtOTcwNi04MGE0Y2FlODBjNjMifQ==",
    with_id="UN-19"
)  # your credentials

title = "CE + uniform"

plt.figure(figsize=(21, 5))

# accuracy
plt.subplot(1, 3, 1)

train_acc_with_add = run['train/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/acc_micro_1'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/acc_micro_1'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('Acc-micro-1')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# calibration error
plt.subplot(1, 3, 2)

train_acc_with_add = run['train/calib'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/calib'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/calib'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/calib'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('calibration error')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# addition loss
plt.subplot(1, 3, 3)

train_acc_with_add = run['train/addition_uniform_loss'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/addition_uniform_loss'].fetch_values()['value'].to_list()

# train_acc_without_add = run['train_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()
# val_acc_without_add = run['val_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('addition loss')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


# plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
# plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')



plt.legend()
plt.tight_layout()
plt.show();
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/e2001092236e/Uncertainty/e/UN-19

# %%
run = neptune.init_run(
    project="e2001092236e/Uncertainty",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxMGYzYjI3OS0xZjAyLTRmMmMtOTcwNi04MGE0Y2FlODBjNjMifQ==",
    with_id="UN-23"
)  # your credentials

title = "CE + StopGrad"

plt.figure(figsize=(21, 5))

# accuracy
plt.subplot(1, 3, 1)

train_acc_with_add = run['train/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/acc_micro_1'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/acc_micro_1'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('Acc-micro-1')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# calibration error
plt.subplot(1, 3, 2)

train_acc_with_add = run['train/calib'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/calib'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/calib'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/calib'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('calibration error')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# addition loss
plt.subplot(1, 3, 3)

train_acc_with_add = run['train/addition_StopGrad_loss'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/addition_StopGrad_loss'].fetch_values()['value'].to_list()

# train_acc_without_add = run['train_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()
# val_acc_without_add = run['val_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('addition loss')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


# plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
# plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')



plt.legend()
plt.tight_layout()
plt.show();
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/e2001092236e/Uncertainty/e/UN-23

# %%
run = neptune.init_run(
    project="e2001092236e/Uncertainty",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxMGYzYjI3OS0xZjAyLTRmMmMtOTcwNi04MGE0Y2FlODBjNjMifQ==",
    with_id="UN-21"
)  # your credentials

title = "Brier + prior(=uniform)"

plt.figure(figsize=(21, 5))

# accuracy
plt.subplot(1, 3, 1)

train_acc_with_add = run['train/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/acc_micro_1'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/acc_micro_1'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('Acc-micro-1')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# calibration error
plt.subplot(1, 3, 2)

train_acc_with_add = run['train/calib'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/calib'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/calib'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/calib'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('calibration error')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# addition loss
plt.subplot(1, 3, 3)

train_acc_with_add = run['train/addition_prior(=uniform)_loss'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/addition_prior(=uniform)_loss'].fetch_values()['value'].to_list()

# train_acc_without_add = run['train_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()
# val_acc_without_add = run['val_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('addition loss')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


# plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
# plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')



plt.legend()
plt.tight_layout()
plt.show();
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/e2001092236e/Uncertainty/e/UN-21

# %%
run = neptune.init_run(
    project="e2001092236e/Uncertainty",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxMGYzYjI3OS0xZjAyLTRmMmMtOTcwNi04MGE0Y2FlODBjNjMifQ==",
    with_id="UN-27"
)  # your credentials

title = "Brier + StopGrad"

plt.figure(figsize=(21, 5))

# accuracy
plt.subplot(1, 3, 1)

train_acc_with_add = run['train/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/acc_micro_1'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/acc_micro_1'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/acc_micro_1'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('Acc-micro-1')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# calibration error
plt.subplot(1, 3, 2)

train_acc_with_add = run['train/calib'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/calib'].fetch_values()['value'].to_list()

train_acc_without_add = run['train_no_add/calib'].fetch_values()['value'].to_list()
val_acc_without_add = run['val_no_add/calib'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('calibration error')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')

plt.legend()
# addition loss
plt.subplot(1, 3, 3)

train_acc_with_add = run['train/addition_StopGrad_loss'].fetch_values()['value'].to_list()
val_acc_with_add = run['val/addition_StopGrad_loss'].fetch_values()['value'].to_list()

# train_acc_without_add = run['train_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()
# val_acc_without_add = run['val_no_add/addition_uniform_loss'].fetch_values()['value'].to_list()


plt.title(title)
plt.ylabel('addition loss')

plt.plot(train_acc_with_add, c='blue', label="train_add")
plt.plot(val_acc_with_add, c='orange', label="val_add")


# plt.plot(train_acc_without_add, c='blue', label="train_no_add", linestyle='--')
# plt.plot(val_acc_without_add, c='orange', label="val_no_add", linestyle='--')



plt.legend()
plt.tight_layout()
plt.show();
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/e2001092236e/Uncertainty/e/UN-27

# %% [markdown]
# ### результаты

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Выводы**
#
# 1. accuracy у всех одинакого, так что сравнивать можно
# 2. addition loss всегда растет с обучением
# 3. Expected Calibration Error на train<->val показывает различную динамику
# 4. ECE меньше, если не брать прибавку.
